# %% [markdown]
# # ETL Pipeline - 2024 Polling Data

# %% [markdown]
# ## Objectives
#
# * Load the raw polling dataset.
# * Inspect the dataset structure and look for key variables.
# * Convert any date fields encountered into a usable date/time format.
# * Remove duplicates and handle any missing values.
# * Save a cleaned dataset for use in later notebooks.
#
# ## Inputs
#
# * generic_ballot_polls.csv (Downloaded from [(https://www.kaggle.com/datasets/iamtanmayshukla/2024-u-s-election-generic-ballot-polling-data)]
# * Python libraries (pandas, numpy, os)
#
# ## Outputs
#
# * A cleaned dataset will be saved to : data/clean/generic_ballot_polls_clean.csv
# * This cleaned dataset will be used in all later notebooks.

# %% [markdown]
# ---

# %% [markdown]
# # Section 1 - Loading The Raw Data

# %% [markdown]
# In this section, we will be :
# * Loading the raw CSV file.
# * Previewing the dataset.
# * Inspecting the dataset types, missing values and summary statistics.
#
# This will be useful in understanding the dataset before working with it.

# %%
import pandas as pd
from pathlib import Path
import os

BASE_DIR = Path().resolve().parent  # goes one level up
df = pd.read_csv(BASE_DIR / "data" / "raw" / "generic_ballot_polls.csv")

# %% [markdown]
# This has loaded the Raw CSV file into a Pandas dataframe and loaded relevant libraries.

# %%
df.info
# Out:
# <bound method DataFrame.info of      poll_id  pollster_id         pollster sponsor_ids   sponsors  \
# 0      87781         1102          Emerson         NaN        NaN
# 1      87760          568           YouGov         352  Economist
# 2      87774          320         Monmouth         NaN        NaN
# 3      87791         1347           Cygnal         NaN        NaN
# 4      87696          568           YouGov         352  Economist
# ..       ...          ...              ...         ...        ...
# 611    83698         1189  Morning Consult         NaN        NaN
# 612    83699         1189  Morning Consult         NaN        NaN
# 613    83700         1189  Morning Consult         NaN        NaN
# 614    83701         1189  Morning Consult         NaN        NaN
# 615    83702         1189  Morning Consult         NaN        NaN
#
#                               display_name  pollster_rating_id  \
# 0                          Emerson College                  88
# 1                                   YouGov                 391
# 2    Monmouth University Polling Institute                 215
# 3                                   Cygnal                  67
# 4                                   YouGov                 391
# ..                                     ...                 ...
# 611                        Morning Consult                 218
# 612                        Morning Consult                 218
# 613                        Morning Consult                 218
# 614                        Morning Consult                 218
# 615                        Morning Consult                 218
#
#                       pollster_rating_name  numeric_grade  pollscore  ...  \
# 0                          Emerson College            2.9       -1.1  ...
# 1                                   YouGov            2.9       -1.1  ...
# 2    Monmouth University Polling Institute            2.9       -0.9  ...
# 3                                   Cygnal            2.1       -1.3  ...
# 4                                   YouGov            2.9       -1.1  ...
# ..                                     ...            ...        ...  ...
# 611                        Morning Consult            1.8       -0.2  ...
# 612                        Morning Consult            1.8       -0.2  ...
# 613                        Morning Consult            1.8       -0.2  ...
# 614                        Morning Consult            1.8       -0.2  ...
# 615                        Morning Consult            1.8       -0.2  ...
#
#     cycle  office_type  seat_number seat_name election_date    stage  \
# 0    2024   U.S. House          NaN   Generic       11/5/24  general
# 1    2024   U.S. House          NaN   Generic       11/5/24  general
# 2    2024   U.S. House          NaN   Generic       11/5/24  general
# 3    2024   U.S. House          NaN   Generic       11/5/24  general
# 4    2024   U.S. House          NaN   Generic       11/5/24  general
# ..    ...          ...          ...       ...           ...      ...
# 611  2024   U.S. House          NaN   Generic       11/5/24  general
# 612  2024   U.S. House          NaN   Generic       11/5/24  general
# 613  2024   U.S. House          NaN   Generic       11/5/24  general
# 614  2024   U.S. House          NaN   Generic       11/5/24  general
# 615  2024   U.S. House          NaN   Generic       11/5/24  general
#
#      nationwide_batch   dem   rep  ind
# 0               False  47.5  45.5  NaN
# 1               False  45.0  44.0  NaN
# 2               False  48.0  46.0  NaN
# 3               False  46.4  47.1  NaN
# 4               False  45.0  44.0  NaN
# ..                ...   ...   ...  ...
# 611             False  47.0  44.0  NaN
# 612             False  48.0  44.0  NaN
# 613             False  48.0  44.0  NaN
# 614             False  48.0  44.0  NaN
# 615             False  47.0  44.0  NaN
#
# [616 rows x 41 columns]>

# %% [markdown]
# This has given us an overview of the dataset, showing column names, data types and non-null counts, heping us identify missing data and column types.

# %%
df.describe(include='all')
# Out:
#              poll_id  pollster_id         pollster sponsor_ids   sponsors  \
# count     616.000000   616.000000              616         193        193
# unique           NaN          NaN               47          31         31
# top              NaN          NaN  Morning Consult         352  Economist
# freq             NaN          NaN              269          59         59
# mean    84598.071429  1060.521104              NaN         NaN        NaN
# std      1564.734963   433.561353              NaN         NaN        NaN
# min     81694.000000   194.000000              NaN         NaN        NaN
# 25%     83517.750000   568.000000              NaN         NaN        NaN
# 50%     83671.500000  1189.000000              NaN         NaN        NaN
# 75%     85911.000000  1189.000000              NaN         NaN        NaN
# max     87791.000000  1888.000000              NaN         NaN        NaN
#
#            display_name  pollster_rating_id pollster_rating_name  \
# count               616          616.000000                  616
# unique               47                 NaN                   45
# top     Morning Consult                 NaN      Morning Consult
# freq                269                 NaN                  269
# mean                NaN          280.863636                  NaN
# std                 NaN          166.227147                  NaN
# min                 NaN           37.000000                  NaN
# 25%                 NaN          218.000000                  NaN
# 50%                 NaN          218.000000                  NaN
# 75%                 NaN          385.000000                  NaN
# max                 NaN          861.000000                  NaN
#
#         numeric_grade   pollscore  ...   cycle  office_type  seat_number  \
# count      576.000000  576.000000  ...   616.0          616          0.0
# unique            NaN         NaN  ...     NaN            1          NaN
# top               NaN         NaN  ...     NaN   U.S. House          NaN
# freq              NaN         NaN  ...     NaN          616          NaN
# mean         1.912674   -0.226910  ...  2024.0          NaN          NaN
# std          0.668623    0.736635  ...     0.0          NaN          NaN
# min          0.500000   -1.300000  ...  2024.0          NaN          NaN
# 25%          1.800000   -0.600000  ...  2024.0          NaN          NaN
# 50%          1.800000   -0.200000  ...  2024.0          NaN          NaN
# 75%          2.400000   -0.200000  ...  2024.0          NaN          NaN
# max          3.000000    1.700000  ...  2024.0          NaN          NaN
#
#        seat_name election_date    stage  nationwide_batch         dem  \
# count        616           616      616               616  616.000000
# unique         1             1        1                 1         NaN
# top      Generic       11/5/24  general             False         NaN
# freq         616           616      616               616         NaN
# mean         NaN           NaN      NaN               NaN   44.544903
# std          NaN           NaN      NaN               NaN    2.017888
# min          NaN           NaN      NaN               NaN   36.000000
# 25%          NaN           NaN      NaN               NaN   43.000000
# 50%          NaN           NaN      NaN               NaN   45.000000
# 75%          NaN           NaN      NaN               NaN   46.000000
# max          NaN           NaN      NaN               NaN   52.000000
#
#                rep  ind
# count   616.000000  0.0
# unique         NaN  NaN
# top            NaN  NaN
# freq           NaN  NaN
# mean     43.834416  NaN
# std       2.248153  NaN
# min      35.000000  NaN
# 25%      43.000000  NaN
# 50%      43.000000  NaN
# 75%      45.015000  NaN
# max      52.000000  NaN
#
# [11 rows x 41 columns]

# %% [markdown]
# This has provided summary statistics for numeric and categorical columns, allowing us to inspect distributions, ranges and identify potential anomalies.

# %%
df.isna().sum()
# Out:
# poll_id                      0
# pollster_id                  0
# pollster                     0
# sponsor_ids                423
# sponsors                   423
# display_name                 0
# pollster_rating_id           0
# pollster_rating_name         0
# numeric_grade               40
# pollscore                   40
# methodology                 30
# transparency_score         377
# state                      616
# start_date                   0
# end_date                     0
# sponsor_candidate_id       616
# sponsor_candidate          616
# sponsor_candidate_party    616
# question_id                  0
# sample_size                  8
# population                   0
# subpopulation              615
# population_full              0
# tracking                   347
# created_at                   0
# notes                      610
# url                          0
# source                     616
# internal                   596
# partisan                   543
# race_id                      0
# cycle                        0
# office_type                  0
# seat_number                616
# seat_name                    0
# election_date                0
# stage                        0
# nationwide_batch             0
# dem                          0
# rep                          0
# ind                        616
# dtype: int64

# %% [markdown]
# This is showing the number of missing values in each column. Key columns with missing values will need to be handled in the ETL process.

# %% [markdown]
# ---

# %% [markdown]
# # Section 2 - Basic Cleaning

# %% [markdown]
# In this section, we will :
# * Convert date columns.
# * Drop duplicate values.
# * Remove any rows with missing key values.
# * Select columns that will be useful to work with.

# %%
date_cols = ["start_date", "end_date"]

for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')
# Out:
# C:\Users\harry\AppData\Local\Temp\ipykernel_4520\3790147647.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# C:\Users\harry\AppData\Local\Temp\ipykernel_4520\3790147647.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')

# %% [markdown]
# This has converted the start_date and end_date columns to a date/time format, allowing time based analysis and ensures that dates are handled properly in later steps.

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (616, 41)

# %% [markdown]
# This has removed duplicate rows to ensure that each poll is only represented once, ensuring they don't clutter the dataset.

# %%
keep_cols = [
    "start_date", "end_date", "pollster", "sample_size", 
    "dem", "rep", "ind", "methodology", "pollster_rating_id",
    "numeric_grade"
]
df = df[keep_cols]
df.head()
# Out:
#   start_date   end_date  pollster  sample_size   dem   rep  ind  \
# 0 2024-08-12 2024-08-14   Emerson       1000.0  47.5  45.5  NaN
# 1 2024-08-11 2024-08-13    YouGov       1407.0  45.0  44.0  NaN
# 2 2024-08-08 2024-08-12  Monmouth        801.0  48.0  46.0  NaN
# 3 2024-08-06 2024-08-08    Cygnal       1500.0  46.4  47.1  NaN
# 4 2024-08-04 2024-08-06    YouGov       1413.0  45.0  44.0  NaN
#
#                     methodology  pollster_rating_id  numeric_grade
# 0  IVR/Online Panel/Text-to-Web                  88            2.9
# 1                  Online Panel                 391            2.9
# 2        Live Phone/Text-to-Web                 215            2.9
# 3                           NaN                  67            2.1
# 4                  Online Panel                 391            2.9

# %% [markdown]
# This has selected the most relevant columns for our analysis, keeping the dataset more focused and easier to work on.

# %%
df = df.dropna(subset=["sample_size", "dem", "rep"])
df.isna().sum()
# Out:
# start_date              0
# end_date                0
# pollster                0
# sample_size             0
# dem                     0
# rep                     0
# ind                   608
# methodology            24
# pollster_rating_id      0
# numeric_grade          40
# dtype: int64

# %% [markdown]
# This has removed rows where key values (sample_size, dem, rep) are missing. This ensures that further analysis on poll results are based on valid data.

# %%
df = df.reset_index(drop=True)
df.head()
# Out:
#   start_date   end_date  pollster  sample_size   dem   rep  ind  \
# 0 2024-08-12 2024-08-14   Emerson       1000.0  47.5  45.5  NaN
# 1 2024-08-11 2024-08-13    YouGov       1407.0  45.0  44.0  NaN
# 2 2024-08-08 2024-08-12  Monmouth        801.0  48.0  46.0  NaN
# 3 2024-08-06 2024-08-08    Cygnal       1500.0  46.4  47.1  NaN
# 4 2024-08-04 2024-08-06    YouGov       1413.0  45.0  44.0  NaN
#
#                     methodology  pollster_rating_id  numeric_grade
# 0  IVR/Online Panel/Text-to-Web                  88            2.9
# 1                  Online Panel                 391            2.9
# 2        Live Phone/Text-to-Web                 215            2.9
# 3                           NaN                  67            2.1
# 4                  Online Panel                 391            2.9

# %% [markdown]
# This resets the index after cleaning so we have a clean index for easier referencing to work on.

# %% [markdown]
# ---

# %% [markdown]
# # Section 3 - Save The Cleaned Dataset

# %% [markdown]
# In this section we will :
# * Create a clean folder for the cleaned dataset (if required)
# * Save the cleaned dataset in the new folder.

# %%
clean_path = "data/clean/generic_ballot_polls_clean.csv"

os.makedirs("data/clean", exist_ok=True)
df.to_csv(clean_path, index=False)

clean_path
# Out:
# 'data/clean/generic_ballot_polls_clean.csv'

# %% [markdown]
# The cleaned dataset is saved to data/clean/generic ballout_polls_clean.csv. If data/clean does not exist, it is created during this step.

# %% [markdown]
# ---

# %% [markdown]
# # Conclusions and Next Steps
#
# # Conclusions
# * The raw dataset has been loaded, inspected and cleaned.
# * Duplicate rows and rows with missing key values were removed.
# * Date columns are now in proper date/time format.
# * Only relevant columns have been retained during the process.
# * The cleaned dataset is saved and ready for use.
#
# # Next Steps
# * Explore the trends in polling results over time.
# * Analyze pollster performance and identify and potential bias.
# * Compare methodologies (online vs telephone) and sample sizes.
# * Visualize the results with line charts, scatter plots and summary statistics.
# * Prepare any additional features or aggregations that may be required for predictive modeling.

# %% [markdown]
# ---
